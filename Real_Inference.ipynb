# %%
from real_utils import *
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 2023-10-15 04:05:36.150432: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# We have prepared __6__ real events for demonstrating our model performance on real data. For each event, we will have the __real signal in the middle__ and take 4096s around it. You can check data source here: https://gwosc.org/eventapi/html/allevents/ We also preprocessed data by whitening and truncation so the total length of data will be about 3850s. Therefore, __the signals occur at ~1925s.__ Plus, when plotting the strains and detections, we will pad zero at truncation part (both ends) so the signal detection should still be at __~2048s__.
# (Note: Due the limit of the computation power on Ocean Capsule reproducible run, we can only show the one (middle) batch inference result. The full version can be seen at __'/root/capsule/data/Real_Inference.html'__.)

# %% [markdown]
# # GW200129_065458

# %%
data_dir = '/root/capsule/data/Feb_Events/GW200129_065458_1264314069.hdf5'
Event = 'GW200129_065458'
Real_Inference(data_dir,Event)
# Out:
# 2023-10-15 04:05:38.948140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 04:05:38.989273: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 04:05:38.991547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-15 04:05:38.993933: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# ...

# %% [markdown]
# # GW200208_130117

# %%
data_dir = '/root/capsule/data/Feb_Events/GW200208_130117_1265200048.hdf5'
Event = 'GW200208_130117'
Real_Inference(data_dir,Event)
# Out:
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200208 model_1 {'detection': [1925.8720703125]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200208 model_2 {'detection': [1925.872802734375]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200208 model_3 {'detection': [1925.872314453125]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200208 model_4 {'detection': [1925.874755859375, 1972.260498046875]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200208 model_5 {'detection': [1925.876708984375]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200208 model_6 {'detection': [1925.8740234375]}
# Ensemble Detection Results: [1925.8720703125]

# %% [markdown]
# # GW200209_085452

# %%
data_dir = '/root/capsule/data/Feb_Events/GW200209_085452_1265271663.hdf5'
Event = 'GW200209_085452'
Real_Inference(data_dir,Event)
# Out:
# ...
# 8/8 [==============================] - 2s 320ms/step
# GW200209 model_1 {'detection': [1925.098876953125]}
# ...
# 8/8 [==============================] - 2s 320ms/step
# GW200209 model_2 {'detection': [1925.103271484375]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200209 model_3 {'detection': [1925.103759765625]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200209 model_4 {'detection': [1925.100830078125]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200209 model_5 {'detection': [1892.134033203125, 1925.0966796875]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200209 model_6 {'detection': [1925.104248046875]}
# Ensemble Detection Results: [1925.098876953125]

# %% [markdown]
# # GW200216_220804

# %%
data_dir = '/root/capsule/data/Feb_Events/GW200216_220804_1265924055.hdf5'
Event = 'GW200216_220804'
Real_Inference(data_dir,Event)
# Out:
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200216 model_1 {'detection': [1925.8115234375]}
# ...
# 8/8 [==============================] - 2s 321ms/step
# GW200216 model_2 {'detection': [1925.81103515625]}
# ...
# 8/8 [==============================] - 2s 320ms/step
# GW200216 model_3 {'detection': [1925.80859375]}
# ...
# 8/8 [==============================] - 2s 320ms/step
# GW200216 model_4 {'detection': [1925.803955078125]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200216 model_5 {'detection': [1925.804931640625]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200216 model_6 {'detection': [1925.80615234375]}
# Ensemble Detection Results: [1925.8115234375]

# %% [markdown]
# # GW200219_094415

# %%
data_dir = '/root/capsule/data/Feb_Events/GW200219_094415_1266138626.hdf5'
Event = 'GW200219_094415'
Real_Inference(data_dir,Event)
# Out:
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200219 model_1 {'detection': [1925.1240234375]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200219 model_2 {'detection': [1925.121826171875]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200219 model_3 {'detection': [1925.122314453125]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200219 model_4 {'detection': [1925.122802734375]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200219 model_5 {'detection': [1925.12548828125]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200219 model_6 {'detection': [1925.123046875]}
# Ensemble Detection Results: [1925.1240234375]

# %% [markdown]
# # GW200224_222234

# %%
data_dir = '/root/capsule/data/Feb_Events/GW200224_222234_1266616125.hdf5'
Event = 'GW200224_222234'
Real_Inference(data_dir,Event)
# Out:
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200224 model_1 {'detection': [1925.3251953125]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200224 model_2 {'detection': [1925.328369140625]}
# ...
# 8/8 [==============================] - 2s 320ms/step
# GW200224 model_3 {'detection': [1925.3291015625]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200224 model_4 {'detection': [1925.32861328125]}
# ...
# 8/8 [==============================] - 2s 320ms/step
# GW200224 model_5 {'detection': [1925.331787109375]}
# ...
# 8/8 [==============================] - 2s 319ms/step
# GW200224 model_6 {'detection': [1925.3291015625]}
# Ensemble Detection Results: [1925.3251953125]
